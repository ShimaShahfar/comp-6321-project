# %%
cd ..
# Out:
# /Users/shimash/UNET

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from models.ICTNet import ICTNet

# %%
model = ICTNet()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# first_conv (Conv2D)             (None, 224, 224, 48) 1344        input_1[0][0]
# __________________________________________________________________________________________________
# down_denseblock1_preact0_bn (Ba (None, 224, 224, 48) 192         first_conv[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 224, 224, 48) 0           down_denseblock1_preact0_bn[0][0]
# __________________________________________________________________________________________________
# ...
